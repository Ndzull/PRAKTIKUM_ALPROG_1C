# %% [markdown]
# 1.

# %%
print(f"a. {11-4%9}")
print(f"b. {5%5}")
print(f"c. {7//4}")
print(f"d. {10**2}")
print(f"e. {9%1}")
print(f"f. {(7-4)/3}")
# Out:
# a. 7
# b. 0
# c. 1
# d. 100
# e. 0
# f. 1.0

# %% [markdown]
# 2.

# %%
print(f"a. {5**2}")
print(f"b. {3+(4*5)}")
print(f"c. {(5+3)//10}")
print(f"d. {100%5}")
print(f"e. {7/4}")
print(f"f. {(pow(2,3)-1)+5}")
# Out:
# a. 25
# b. 23
# c. 0
# d. 0
# e. 1.75
# f. 12

# %% [markdown]
# 3. var1 = var2 bermaksud memberikan nilai dari var2 ke var1. Jadi, setelah perintah ini dijalankan, var1 akan memiliki nilai yang sama dengan var2.<br>
# sedangkan var1 = var2 bermaksud memberikan nilai dari var1 ke var2. Jadi, setelah perintah ini dijalankan, var2 akan memiliki nilai yang sama dengan var1.<br>

# %% [markdown]
# 4.

# %%
a = 3
print(f"1. nilai a: {a}")
b = a+5
print(f"2. nilai b: {b}")
a = a**b
print(f"3. nilai a: {a}")
print(f"4. nilai {(a/b)+2}")
b = b%2+0.7
print(f"5. nilai b: {b}")
# Out:
# 1. nilai a: 3
# 2. nilai b: 8
# 3. nilai a: 6561
# 4. nilai 822.125
# 5. nilai b: 0.7

# %%
bal=100
print(bal)
inter=0.05
print(bal,inter)
withDr=25
print(bal,inter,withDr)
bal+=(inter*bal)
print(bal,inter,withDr)
bal=bal-withDr
print(bal,inter,withDr)
# Out:
# 100
# 100 0.05
# 100 0.05 25
# 105.0 0.05 25
# 80.0 0.05 25

# %%
a=7
b=4
print(a*b**2)
# Out:
# 112

# %%
n=6
n**=4
print(n/5)
# Out:
# 259.2

# %%
totalBeries= 1000
totalCost=450
eachBery=totalCost/totalBeries
print(eachBery)

# %%
0.05 = interest
balance = 800
print(balance)
print(interest*balance)

# %%
interest = 0.05
balance = 800
print(balance)
print(interest*balance)
# Out:
# 800
# 40.0

# %%
int(7.75)
# Out:
# 7

# %%
int(9-2)
# Out:
# 7

# %%
round(-7.5)
# Out:
# -8

# %%
round(7.1254,3)
# Out:
# 7.125

# %%
b=8
int(b*0.5)
# Out:
# 4

# %%
a=7
abs(a-5)
# Out:
# 2

# %% [markdown]
# 18. Hitung Keutungan.
# Langkah-langkah berikut menghitung laba perusahaan.
# (a) Buat pendapatan variabel dan berikan nilai 100.456
# (b) Buat biaya variabel dan berikan nilai 55.500
# (c) Buat variabel laba dan tetapkan perbedaan antara nilai-nilai variabel pendapatan dan biaya.
# (d) menampilkan nilai variabel laba.

# %%
pendapatan = 100.456
biaya = 55.500
laba = pendapatan - biaya
print(laba)
# Out:
# 44.956

# %% [markdown]
# 19. Keuntungan dari saham
# (a) Buat variabel harga pembelian dan berikan nilai 20
# (b) Buat variabel harga penjualan dan berikan nilai 30
# (c) buat variabel persentase profit dan tetapkan 100 kali dari nilai selisih antara harga jual dan harga beli dibagi dengan harga pembelian
# (d) menampilkan nilai variabel persentase profit.

# %%
harga_pembelian = 20
harga_penjualan = 30
persentase_profit = 100 * (harga_penjualan - harga_pembelian) / harga_pembelian
print(persentase_profit)
# Out:
# 50.0

# %% [markdown]
# 20. Savings Account. Langkah-langkah berikut menghitung saldo pada akhir tiga tahun ketika $100 disetor pada awal setiap tahun dalam rekening tabungan dengan bunga 5% ditambah setiap tahun,
# (a) Buat saldo variabel dan berikan nilai 100,
# (b) Tingkatkan nilai saldo variabel sebesar 5%, dan tambahkan 100 untuk itu.
# (c) Tingkatkan nilai saldo variabel sebesar 5%. dan tambahkan 100 ke dalamnya.
# (d) Meningkatkan nilai saldo variabel sebesar 5%.
# (e) Menampilkan nilai keseimbangan (dibulatkan menjadi dua tempat desimal),

# %%
saldo = 100
saldo = saldo + (saldo * 0.05) + 100
saldo = saldo + (saldo * 0.05) + 100
saldo = saldo + (saldo * 0.05)
print(round(saldo, 2))
# Out:
# 331.01
