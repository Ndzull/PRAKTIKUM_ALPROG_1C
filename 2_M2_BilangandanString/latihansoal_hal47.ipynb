# %%
print("Institut Teknologi Sepuluh Nopember")
# Out:
# Institut Teknologi Sepuluh Nopember

# %%
var="Hello"
print(var)
# Out:
# Hello

# %%
"Python"[4]
# Out:
# 'o'

# %%
"Python"[2:2]
# Out:
# ''

# %%
"Python".find("Pyt")
# Out:
# 0

# %%
"python/java/c++".split("/")
# Out:
# ['python', 'java', 'c++']
